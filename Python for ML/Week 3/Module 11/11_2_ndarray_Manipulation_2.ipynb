# %%
import numpy as np

mat = np.array([[10,20,30] ,
                [30,40,50]
                ])

trans = mat.T

print(trans)
# Out:
# [[10 30]
#  [20 40]
#  [30 50]]

# %%
#array Split
a = np.random.randint(1,10, size =(10,))
print(a)

splitted_arr = np.array_split(a, 3)
print(splitted_arr)

#Equally Split
splitted_arr = np.split(a, 2)
print(splitted_arr)
# Out:
# [5 6 3 7 9 7 2 4 8 6]
# [array([5, 6, 3, 7], dtype=int32), array([9, 7, 2], dtype=int32), array([4, 8, 6], dtype=int32)]
# [array([5, 6, 3, 7, 9], dtype=int32), array([7, 2, 4, 8, 6], dtype=int32)]
