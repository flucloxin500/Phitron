# %%
import pandas as pd
import numpy as np  

csv_data = pd.read_csv('student_data (1).csv')

csv_data['FullName']
# Out:
# 0          Alif Rahman
# 1        Fatima Akhter
# 2        Imran Hossain
# 3     Jannatul Ferdous
# 4          Kamal Uddin
# 5          Laila Begum
# 6       Mahmudul Hasan
# 7          Nadia Islam
# 8           Omar Faruq
# 9         Priya Sharma
# 10        Rahim Sheikh
# 11     Sadia Chowdhury
# 12        Tanvir Ahmed
# 13          Urmi Akter
# 14        Wahiduzzaman
# 15        Ziaur Rahman
# 16         Afsana Mimi
# 17         Babul Ahmed
# 18        Faria Rahman
# 19          Nasir Khan
# Name: FullName, dtype: object

# %%
#Loc [row(index), column(name)]

csv_data.loc[2]
print(type(csv_data.loc[2]))

#Multiple rows

csv_data.loc[[2,4,16]]

#Range of rows
csv_data.loc[2:5]

csv_data.loc[:, ['Python Marks','Algorithm Marks']]
print(type(csv_data.loc[:, ['Python Marks','Algorithm Marks']]))

csv_data.loc[:,'CompletionStatus']
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# 0       Completed
# 1     In Progress
# 2       Completed
# 3       Completed
# 4     In Progress
# 5       Completed
# 6     In Progress
# 7       Completed
# 8       Completed
# 9       Completed
# 10    In Progress
# 11      Completed
# 12      Completed
# 13    Not Started
# 14      Completed
# 15    In Progress
# 16      Completed
# 17      Completed
# 18    Not Started
# 19      Completed
# Name: CompletionStatus, dtype: object
