# %%
import pandas as pd

data =pd.DataFrame( {
    'Product': ['Pen', 'Book', 'Eraser', 'Pencil'],
    'Price': [10, 50, 5, 7],
    'Quantity': [100, 60, 200, 150]
})

print(data.loc[0])

print(data.loc[:, 'Price'])

print(data.loc[1:2, 'Product':'Quantity'])

print(data.iloc[0])

print(data.iloc[:, 2])

print(data.iloc[1:3, 0:2])

data
# Out:
# Product     Pen
# Price        10
# Quantity    100
# Name: 0, dtype: object
# 0    10
# 1    50
# 2     5
# 3     7
# Name: Price, dtype: int64
#   Product  Price  Quantity
# 1    Book     50        60
# 2  Eraser      5       200
# Product     Pen
# Price        10
# Quantity    100
# Name: 0, dtype: object
# 0    100
# 1     60
# 2    200
# 3    150
# Name: Quantity, dtype: int64
#   Product  Price
# 1    Book     50
# 2  Eraser      5
#   Product  Price  Quantity
# 0     Pen     10       100
# 1    Book     50        60
# 2  Eraser      5       200
# 3  Pencil      7       150
