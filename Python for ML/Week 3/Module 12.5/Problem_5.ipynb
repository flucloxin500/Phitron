# %%
import pandas as pd

data =pd.DataFrame( {
    'Name': ['Walid', 'Rasim', 'Fahim', 'Nakib'],
    'Math': [70, 50, 85, 75],
    'English': [90, 80, 95, 75]
})

data
data.drop('Math', axis=1, inplace=True)
data
data.drop(index=2, inplace=True)
data
# Out:
#     Name  English
# 0  Walid       90
# 1  Rasim       80
# 3  Nakib       75
