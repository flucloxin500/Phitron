# %%
import pandas as pd

numbers = [10, 20, 30, 40, 50]
s = pd.Series(numbers)

s
print(s.index)
s.dtypes

df = pd.DataFrame({
    "Name": ["Ayesha", "Rafi", "Nusrat", "Tanvir"],
    "Age": [22, 25, 21, 27],
    "City": ["Dhaka", "Chattogram", "Sylhet", "Rajshahi"]
})

df
# Out:
# RangeIndex(start=0, stop=5, step=1)
#      Name  Age        City
# 0  Ayesha   22       Dhaka
# 1    Rafi   25  Chattogram
# 2  Nusrat   21      Sylhet
# 3  Tanvir   27    Rajshahi
