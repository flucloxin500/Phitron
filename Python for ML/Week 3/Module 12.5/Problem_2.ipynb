# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Ayesha", "Rafi", "Nusrat", "Tanvir"],
    "Age": [22, 25, 21, 27],
    "City": ["Dhaka", "Chattogram", "Sylhet", "Rajshahi"]
})


df.shape
df.dtypes
df.columns
df.describe()
df.describe(include='all')
# Out:
#           Name        Age   City
# count        4   4.000000      4
# unique       4        NaN      4
# top     Ayesha        NaN  Dhaka
# freq         1        NaN      1
# mean       NaN  23.750000    NaN
# std        NaN   2.753785    NaN
# min        NaN  21.000000    NaN
# 25%        NaN  21.750000    NaN
# 50%        NaN  23.500000    NaN
# 75%        NaN  25.500000    NaN
# max        NaN  27.000000    NaN
