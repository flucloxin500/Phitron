# %%
import pandas as pd

data =pd.DataFrame( {
    'Product': ['Pen', 'Book', 'Eraser', 'Pencil'],
    'Price': [10, 50, 5, 7],
    'Quantity': [100, 60, 200, 150]
})

data
data.columns
#data.index
data['Product']
data.loc[0]
# Out:
# Product     Pen
# Price        10
# Quantity    100
# Name: 0, dtype: object
