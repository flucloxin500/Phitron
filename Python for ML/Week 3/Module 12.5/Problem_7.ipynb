# %%
import pandas as pd

data =pd.DataFrame( {
    'Name': ['Walid', 'Rasim', 'Fahim', 'Nakib','Minhaj','Nayem', 'Sakib','Mehraz'],
    'Score': [45, 100, 50, 67, 89, 78, 56, 90],
})

sixty = data.loc[(data['Score'] > 60)]
sixty
forty = data.loc[(data['Score'] < 40)]
forty
# Out:
# Empty DataFrame
# Columns: [Name, Score]
# Index: []
