# %%
import numpy as np
import pandas as pd

np.random.seed(42)

ids = np.arange(1, 11)
ages = np.random.randint(18, 60, 10)
salaries = np.random.randint(30000, 90000, 10)
departments = np.array(["HR", "IT", "Finance", "IT", "HR", "Sales", "Finance", "IT", "Sales", "HR"])

DF = pd.DataFrame({
"id": ids,
"age": ages,
"salary": salaries,
"dept": departments
})

DF.to_csv("employees.csv", index=False)
print("Sample Data Created and Saved as employees.csv")
# Out:
# Sample Data Created and Saved as employees.csv

# %% [markdown]
# ### Q1

# %%
ages_arr = np.array(ages)
print("Ages: ", ages_arr)
print("Dtype :", ages_arr.dtype)
print("Ndim : ", ages_arr.ndim)
print("Shape : ", ages_arr.shape)
print("Size : ", ages_arr.size)


salaries_arr = np.array(salaries)
print("Ages: ", salaries_arr)
print("Dtype :", salaries_arr.dtype)
print("Ndim : ", salaries_arr.ndim)
print("Shape : ", salaries_arr.shape)
print("Size : ", salaries_arr.size)
# Out:
# Ages:  [56 46 32 25 38 56 36 40 28 28]
# Dtype : int32
# Ndim :  1
# Shape :  (10,)
# Size :  10
# Ages:  [77191 74131 46023 71090 31685 30769 89735 86101 32433 35311]
# Dtype : int32
# Ndim :  1
# Shape :  (10,)
# Size :  10

# %% [markdown]
# ### Q2

# %%
high_sal = np.max(salaries_arr)
Low_sal = np.min(salaries_arr)
print("Highest Salary: ", high_sal)
print("Lowest Salary: ", Low_sal)

avg_sal = np.mean(salaries_arr)
print("Average Salary: ", avg_sal)

ave_age = np.mean(ages_arr)
print("Average Age: ", ave_age)
# Out:
# Highest Salary:  89735
# Lowest Salary:  30769
# Average Salary:  57446.9
# Average Age:  38.5

# %% [markdown]
# ### Q3

# %%
gr_than_3o = np.array(ages_arr[ages_arr >30])
print("All ages greater than 30: ",gr_than_3o)

cnt_30 = np.count_nonzero(gr_than_3o)
print("Employees older than 30 : ",cnt_30)
# Out:
# All ages greater than 30:  [56 46 32 38 56 36 40]
# Employees older than 30 :  7

# %% [markdown]
# ### Q4

# %%
updated_ages  = ages_arr +5
print("Ages +5: ", updated_ages)
print("Ages: ", ages_arr)
# Out:
# Ages +5:  [61 51 37 30 43 61 41 45 33 33]
# Ages:  [56 46 32 25 38 56 36 40 28 28]

# %% [markdown]
# ### Q5

# %%
print(salaries_arr)

sum_sal = np.sum(salaries_arr)
print("Sum of all salary: ",sum_sal)

dif_sal = (high_sal -Low_sal )
print("Diff of high and low salary: ",dif_sal)
# Out:
# [77191 74131 46023 71090 31685 30769 89735 86101 32433 35311]
# Sum of all salary:  574469
# Diff of high and low salary:  58966
