# %%
num = input()
a = int(num)
lst = []
sum = 0


for x in range(len(num)):
  b = int(a%10)
  a = int(a/10)
  lst.append(b)

for x in lst:
  result = 1

  for i in range(1,x+1):
    result = result*i

  sum+=res



if sum == int(num):
  print("Strong Number")
else:
  print("Not Strong Number")
# Out:
# Strong Number
