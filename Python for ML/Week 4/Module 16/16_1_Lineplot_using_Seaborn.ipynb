# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

student = pd.read_csv('sns_data (1).csv')
student.head(5)
# Out:
#    student_id class_level   subject  study_hours  test_score  week  \
# 0           1    Freshman      Math            5          78     1
# 1           2    Freshman   Science            3          65     1
# 2           3    Freshman   History            4          70     1
# 3           4    Freshman  Language            2          60     1
# 4           5   Sophomore      Math            6          82     1
#
#    attendance_rate  gender  hostel  Tshirt_size
# 0               90    Male    True           30
# 1               80  Female   False           20
# 2               85    Male    True           20
# 3               75  Female    True           40
# 4               92    Male    True           20

# %%
#Axes level wise attendance rate

sns.lineplot(x='week', y='attendance_rate', data=student,errorbar=None,hue='gender')
# Out:
# <Axes: xlabel='week', ylabel='attendance_rate'>

# %%
#Figure level wise attendance rate
sns.relplot(kind='line',x='week', y='attendance_rate', data=student,errorbar=None,hue='gender')

# %%
sns.relplot(kind='line',x='week', y='test_score', data=student,errorbar=None,hue='class_level')
