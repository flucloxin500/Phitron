# %%
# Correlation
## Positive correlation: As one variable increases, the other variable also increases.
## Negative correlation: As one variable increases, the other variable decreases.

## Outliers can significantly affect the correlation between two variables. They can either inflate or deflate the correlation coefficient, leading to misleading interpretations of the relationship between the variables. It is important to identify and address outliers when analyzing correlations to ensure accurate results.
