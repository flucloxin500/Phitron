# %%
import numpy as np

x = np.array([10, 25, 30, 49, 50])
y = np.array([12, 24, 33, 47, 52])

g_than = x > y
print(g_than)
equal = x == y
print(equal)

print(np.all(g_than))
print(np.any(g_than))
# Out:
# [False  True False  True False]
# [False False False False False]
# False
# True
