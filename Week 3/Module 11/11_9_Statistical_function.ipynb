# %%
import numpy as np

a = np.random.randint(1,100,size=(100,))
print(a)
# Out:
# [25 79 38 20 71 99 97 93 45 96 14 79 36 16 25 31 92 71 16 32 60 68 98 53
#  31 92 46 33 39 89 97 83  2 55 10 20 41 26 57  5 25 58 51 83 20  2 56 32
#  58 83  5 91 49 66 66 35 93 33  8 31 56 13 48 57 29 56 97  5  6 15 76 91
#  65  7 38 53 25 18 96  8 12 88 55 39 60 85 64 48 43 98 33 98 86 18 87 57
#  10 40 64 84]
